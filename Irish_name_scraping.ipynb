# %%
import pandas as pd
import lxml             # Needed for read_html function.
                        # This imports fine on my machine; may need to be pip- or conda-installed on IBM server
import numpy as np
import requests

# %%
names_url = r"https://www.irelandbeforeyoudie.com/ranked-top-100-irish-surnames-and-meanings"

# %%
# Pretend to be a browser, to avoid a 403: Forbidden error when scraping

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(names_url, headers = header)
df = pd.read_html(r.text)

# %%
len(df)
# Out:
# 11

# %%
df[-1]
# Out:
#         0           1                  2                      3
# 0    Rank        Name  Gaelic Equivalent                Meaning
# 1       1      Murphy        ó Murchadha            sea-battler
# 2       2       Kelly        ó Ceallaigh          bright-headed
# 3       3  O’Sullivan     ó Súilleabháin              dark-eyed
# 4       4       Walsh         Breathnach               Welshman
# ..    ...         ...                ...                    ...
# 96     96  MacDermott       Mac Diarmada     free from jealousy
# 97     97      Molony     ó Maolomhnaigh  servant of the Church
# 98     98    O’Rourke           ó Ruairc                    NaN
# 99     99     Buckley        ó Buachalla               cow herd
# 100   100     O’Dwyer          ó Dubhuir                  black
#
# [101 rows x 4 columns]

# %%
# I'll extract all the names and Gaelic equivalents to a list:
names_list = df[-1][1].tolist()         # the English names
names_list += df[-1][2].tolist()         # the Gaelic names

# %%
names_list
# Out:
# ['Name',
#  'Murphy',
#  'Kelly',
#  'O’Sullivan',
#  'Walsh',
#  'Smith',
#  'O’Brien',
#  'Byrne',
#  'Ryan',
#  'O’Connor',
#  'O’Neill',
#  'O’Reilly',
#  'Doyle',
#  'McCarthy',
#  'Gallagher',
#  'O’Doherty',
#  'Kennedy',
#  'Lynch',
#  'Murray',
#  'Quinn',
#  'Moore',
#  'McLoughlin',
#  'O’Carroll',
#  'Connolly',
#  'Daly',
#  'O’Connell',
#  'Wilson',
#  'Dunne',
#  'Brennan',
#  'Burke',
#  'Collins',
#  'Campbell',
#  'Clarke',
#  'Johnston',
#  'Hughes',
#  'O’Farrell',
#  'Fitzgerald',
#  'Brown',
#  'Martin',
#  'Maguire',
#  'Nolan',
#  'Flynn',
#  'Thompson',
#  'O’Callaghan',
#  'O’Donnell',
#  'Duffy',
#  'O’Mahony',
#  'Boyle',
#  'Healy',
#  'O’Shea',
#  'White',
#  'Sweeney',
#  'Hayes',
#  'Kavanagh',
#  'Power',
#  'McGrath',
#  'Moran',
#  'Brady',
#  'Stewart',
#  'Casey',
#  'Foley',
#  'Fitzpatrick',
#  'O’Leary',
#  'McDonnell',
#  'MacMahon',
#  'Donnelly',
#  'Regan',
#  'Donovan',
#  'Burns',
#  'Flanagan',
#  'Mullan',
#  'Barry',
#  'Kane',
#  'Robinson',
#  'Cunningham',
#  'Griffin',
#  'Kenny',
#  'Sheehan',
#  'Ward',
#  'Whelan',
#  'Lyons',
#  'Reid',
#  'Graham',
#  'Higgins',
#  'Cullen',
#  'Keane',
#  'King',
#  'Maher',
#  'MacKenna',
#  'Bell',
#  'Scott',
#  'Hogan',
#  'O’Keeffe',
#  'Magee',
#  'MacNamara',
#  'MacDonald',
#  'MacDermott',
#  'Molony',
#  'O’Rourke',
#  'Buckley',
#  'O’Dwyer',
#  'Gaelic Equivalent',
#  'ó Murchadha',
#  'ó Ceallaigh',
#  'ó Súilleabháin',
#  'Breathnach',
#  'Mac Gabhann',
#  'ó Briain',
#  'ó Broin',
#  'ó Maoilriain',
#  'ó Conchobhair',
#  'ó Néill',
#  'ó Raghallaigh',
#  'ó Dubhghaill',
#  'Mac Carthaigh',
#  'ó Gallchobhair',
#  'ó Dochartaigh',
#  'ó Cinnéide',
#  'ó Loinsigh',
#  'ó Muireadhaigh',
#  'ó Cuinn',
#  'ó Mordha',
#  'Mac Lochlainn',
#  'ó Cearbhaill',
#  'ó Conghaile',
#  'ó Dálaigh',
#  'ó Conaill',
#  'Mac Liam',
#  'ó Duinn',
#  'ó Braonáin',
#  'de Búrca',
#  'ó Coileáin',
#  nan,
#  'óCléirigh',
#  'Mac Seáin',
#  'ó hAodha',
#  'ó Fearghail',
#  'Mac Gearailt',
#  'Mac an Bhreithiún',
#  'Mac Giolla Mháirtín',
#  'Mag Uidhir',
#  'ó Nualláin',
#  'ó Floinn',
#  'Mac Tomáis',
#  'ó Ceallacháin',
#  'ó Domhnaill',
#  'ó Dufaigh',
#  'ó Mathúna',
#  'ó Baoill',
#  'ó hÉalaighthe',
#  'ó Séaghdha',
#  'Mac Giolla Bháin',
#  'Mac Suibhne',
#  'ó hAodha',
#  'Caomhánach',
#  'de Paor',
#  'Mac Craith',
#  'ó Móráin',
#  'Mac Brádaigh',
#  'Stiobhard',
#  'ó Cathasaigh',
#  'ó Foghladh',
#  'Mac Giolla Phádraig',
#  'ó Laoghaire',
#  'Mac Domhnaill',
#  'Mac Mathúna',
#  'ó Donnghaile',
#  'ó Riagáin',
#  'ó Donnabháin',
#  nan,
#  'ó Flannagáin',
#  'ó Maoláin',
#  'de Barra',
#  'ó Catháin',
#  nan,
#  nan,
#  'ó Gríofa',
#  'ó Cionaoith',
#  'O’Siodhachain',
#  'Mac an Bhaird',
#  'ó Faoláin',
#  'ó Laighin',
#  nan,
#  nan,
#  'ó hUiginn',
#  'ó Cuilinn',
#  'Mac Catháin',
#  'ó Cionga',
#  'Meagher',
#  'Mac Cionaoith',
#  'Mac Giolla Mhaoil',
#  nan,
#  'ó hÓgáin',
#  'ó Caoimh',
#  'Mag Aoidh',
#  'Mac Conmara',
#  'Mac Dónaill',
#  'Mac Diarmada',
#  'ó Maolomhnaigh',
#  'ó Ruairc',
#  'ó Buachalla',
#  'ó Dubhuir']

# %%
# remove the 'nan' entries, which are of type float, and the initial 'Name' entry:
names_list = [el for el in names_list if type(el) == str]
names_list = names_list[1:]

# %%
len(names_list)
# Out:
# 194

# %%
# I'll also grab the "List of streets and squares in Dublin" from 
# Wikipedia -- the "English" column, the "Irish" column, the "Continuations" and "Termini" columns:
dublin_url = r"https://en.wikipedia.org/wiki/List_of_streets_and_squares_in_Dublin"
dub_df = pd.read_html(dublin_url)

# %%
dub_df = dub_df[0]

# %%
dub_df
# Out:
#             English Street or square name  \
# 0                            Abbey Street
# 1                          Ailesbury Road
# 2                           Amiens Street
# 3                           Anglesea Road
# 4   Anne Street South (South Anne Street)
# ..                                    ...
# 66                         Thormanby Road
# 67                       Tritonville Road
# 68                        Werburgh Street
# 69                           Westland Row
# 70                      Winetavern Street
#
#                  Irish Street or square name[1][2][3]  Date[4]  \
# 0                               Sráid na Mainistreach   1728.0
# 1                  Bóthar Ailesbury, Bóthar Aelsbaire      NaN
# 2                                        Sráid Amiens   1800.0
# 3                                          Bóthar Mon      NaN
# 4                                    Sráid Anna Theas   1723.0
# ..                                                ...      ...
# 66                                                NaN      NaN
# 67                                 Bóthar Tritonville      NaN
# 68  Sráid San Werburgh, Sráid San Werburga, Sráid ...   1257.0
# 69                                    Rae an Iarthair   1773.0
# 70                                    Sráid an Fhíona   1329.0
#
#    Historical names[5][6] Route number[7] Dublin postal district  \
# 0                     NaN             NaN                      1
# 1                     NaN            R824                      4
# 2       The Strand (1728)            R105                      1
# 3                     NaN            R815                      4
# 4        South St Anne St             NaN                      2
# ..                    ...             ...                    ...
# 66                    NaN     R105 (part)                     13
# 67                    NaN             NaN                      4
# 68                    NaN             NaN                      2
# 69             Westland's             NaN                      2
# 70   Taverner's St (1311)             NaN                      2
#
#          Sections                              Continuations  \
# 0   Lwr, mid, upr                               Mary's Abbey
# 1             NaN                                        NaN
# 2             NaN                                N Strand Rd
# 3             NaN                                 Beaver Row
# 4             NaN                                   Harry St
# ..            ...                                        ...
# 66            NaN                                        NaN
# 67            NaN                               Irishtown Rd
# 68            NaN                                   Bride St
# 69            NaN                             Lombard Street
# 70            NaN  O'Donovan Rossa Bridge, St Michael's Hill
#
#                       Termini and major cross-streets
# 0                              Beresford St, Capel St
# 1        Sydney Parade Ave, Merrion Rd, Stillorgan Rd
# 2   Memorial Rd/Beresford Pl, Talbot St, Portland ...
# 3                       Merrion Road, Stillorgan Road
# 4                               Grafton St, Dawson St
# ..                                                ...
# 66                           Main St, Carrickbrack Rd
# 67  Londonbridge Rd/Church Ave, Claremont Rd/Serpe...
# 68  Christchurch Pl/Lord Edward St, Bull Alley St/...
# 69                        Pearse Street/Lincoln Place
# 70     Merchant's Qy/Wood Qy, High St/Christchurch Pl
#
# [71 rows x 9 columns]

# %%
# Replace the slashes in the last column with commas:
df_mask = dub_df['Termini and major cross-streets'].str.contains("/", na=False)
dub_df['Termini and major cross-streets'].mask(df_mask, dub_df['Termini and major cross-streets'].str.replace("/", ", ").replace(" ,", ","), inplace=True)

# %%
dub_df
# Out:
#             English Street or square name  \
# 0                            Abbey Street
# 1                          Ailesbury Road
# 2                           Amiens Street
# 3                           Anglesea Road
# 4   Anne Street South (South Anne Street)
# ..                                    ...
# 66                         Thormanby Road
# 67                       Tritonville Road
# 68                        Werburgh Street
# 69                           Westland Row
# 70                      Winetavern Street
#
#                  Irish Street or square name[1][2][3]  Date[4]  \
# 0                               Sráid na Mainistreach   1728.0
# 1                  Bóthar Ailesbury, Bóthar Aelsbaire      NaN
# 2                                        Sráid Amiens   1800.0
# 3                                          Bóthar Mon      NaN
# 4                                    Sráid Anna Theas   1723.0
# ..                                                ...      ...
# 66                                                NaN      NaN
# 67                                 Bóthar Tritonville      NaN
# 68  Sráid San Werburgh, Sráid San Werburga, Sráid ...   1257.0
# 69                                    Rae an Iarthair   1773.0
# 70                                    Sráid an Fhíona   1329.0
#
#    Historical names[5][6] Route number[7] Dublin postal district  \
# 0                     NaN             NaN                      1
# 1                     NaN            R824                      4
# 2       The Strand (1728)            R105                      1
# 3                     NaN            R815                      4
# 4        South St Anne St             NaN                      2
# ..                    ...             ...                    ...
# 66                    NaN     R105 (part)                     13
# 67                    NaN             NaN                      4
# 68                    NaN             NaN                      2
# 69             Westland's             NaN                      2
# 70   Taverner's St (1311)             NaN                      2
#
#          Sections                              Continuations  \
# 0   Lwr, mid, upr                               Mary's Abbey
# 1             NaN                                        NaN
# 2             NaN                                N Strand Rd
# 3             NaN                                 Beaver Row
# 4             NaN                                   Harry St
# ..            ...                                        ...
# 66            NaN                                        NaN
# 67            NaN                               Irishtown Rd
# 68            NaN                                   Bride St
# 69            NaN                             Lombard Street
# 70            NaN  O'Donovan Rossa Bridge, St Michael's Hill
#
#                       Termini and major cross-streets
# 0                              Beresford St, Capel St
# 1        Sydney Parade Ave, Merrion Rd, Stillorgan Rd
# 2   Memorial Rd, Beresford Pl, Talbot St, Portland...
# 3                       Merrion Road, Stillorgan Road
# 4                               Grafton St, Dawson St
# ..                                                ...
# 66                           Main St, Carrickbrack Rd
# 67  Londonbridge Rd, Church Ave, Claremont Rd, Ser...
# 68  Christchurch Pl, Lord Edward St, Bull Alley St...
# 69                       Pearse Street, Lincoln Place
# 70   Merchant's Qy, Wood Qy, High St, Christchurch Pl
#
# [71 rows x 9 columns]

# %%
en_streets_list = dub_df["English Street or square name"].tolist()
ei_streets_list = dub_df["Irish Street or square name[1][2][3]"].tolist()
en_streets_list += dub_df["Continuations"].tolist()
en_streets_list += dub_df["Termini and major cross-streets"].tolist()
# (I'm a bit uncertain about adding the last two columns to the English streets
# list, but am OK either way)

# %%
# I could have removed 'nan's during the list generation, but I'll do it now:
en_streets_list = [el for el in en_streets_list if type(el) == str]
ei_streets_list = [el for el in ei_streets_list if type(el) == str]

# %%
en_streets_list
# Out:
# ['Abbey Street',
#  'Ailesbury Road',
#  'Amiens Street',
#  'Anglesea Road',
#  'Anne Street South (South Anne Street)',
#  'Baggot Street',
#  'Bayside Boulevard',
#  'Bridge Street',
#  'Capel Street',
#  'Carrickbrack Road',
#  'Clyde Road',
#  'College Green',
#  'Dame Street',
#  'Dawson Street',
#  'Dorset Street',
#  'Drumcondra Road',
#  'East Wall Road',
#  'Eccles Street',
#  'Ely Place',
#  'Fishamble Street',
#  'Fitzwilliam Square',
#  'Gardiner Street',
#  'Gilford Road',
#  'Grafton Street',
#  'Greenfield Road',
#  'Henrietta Street',
#  'Henry Street',
#  'Herbert Park',
#  'Herbert Road',
#  'Heytesbury Street',
#  'Howth Road',
#  'Kildare Street',
#  'Leeson Street',
#  'Marlborough Street',
#  'Marrowbone Lane',
#  'Merrion Road',
#  'Merrion Square',
#  'Merrion Street',
#  'Molesworth Street',
#  'Mountjoy Square',
#  'Naas Road',
#  'Nassau Street',
#  'Newbridge Avenue',
#  'North Circular Road',
#  "North Great George's Street",
#  'North Strand Road',
#  'Nutley Lane',
#  "O'Connell Street",
#  'Park Avenue',
#  'Parliament Street',
#  'Parnell Square',
#  'Parnell Street',
#  'Pearse Street',
#  'Pembroke Road',
#  'Raglan Road',
#  "St John's Road East (St John's Road)",
#  "St Stephen's Green",
#  'Sandymount Avenue',
#  'Serpentine Avenue',
#  'South Circular Road',
#  'Stillorgan Road',
#  'Sydney Parade Avenue',
#  'Talbot Street',
#  'Temple Bar',
#  'Templeogue Road',
#  'Templeville Road',
#  'Thormanby Road',
#  'Tritonville Road',
#  'Werburgh Street',
#  'Westland Row',
#  'Winetavern Street',
#  "Mary's Abbey",
#  'N Strand Rd',
#  'Beaver Row',
#  'Harry St',
#  'Merrion Row, Pembroke Rd',
#  'Verbena Lawn (Plásóg Bheirbhéine)',
#  'Fr Mathew Bridge (Droichead an Athar Maitiú)',
#  'Grattan Bridge (Droichead Grattan)',
#  'Greenfield Rd (Bóthar an Ghoirt Ghlais)',
#  'Wellington Pl',
#  'College Green, Lord Edward St',
#  'Drumcondra Rd, Bolton St',
#  'Dorset St Lwr, Swords Rd',
#  'East-Link Toll Bridge, Poplar Row',
#  'Temple St N',
#  'Merrion St Upr',
#  'Synnott Place',
#  'Seafort Ave',
#  'Westmoreland St',
#  'Station Rd, Carrickbrack Rd',
#  'Earl St N, Mary St',
#  'Marlborough Rd',
#  'Stamer St, New Bridge St',
#  'Dublin Rd',
#  'Morehampton Rd',
#  'Thomas Court',
#  'Pembroke Rd, Rock Rd',
#  'Merrion Square W, Ely Place',
#  'Tyrconnell Rd',
#  'Suffolk St, Leinster St S',
#  'Sandymount Rd',
#  'Portland Row',
#  'Amiens St, Annesley Bridge Rd',
#  'Greenfield Park',
#  "O'Connell Bridge, Parnell Sq E",
#  'Grattan Bridge',
#  'Parnell St',
#  'Little Britain St, Summerhill',
#  'College St, Ringsend Rd',
#  'Baggot St Upr, Merrion Rd',
#  'Simmonscourt Rd',
#  'Harrington St',
#  'Bray Rd',
#  'Earl St N',
#  'Essex St E, Fleet St',
#  'Terenure Place, Tallaght Road',
#  'Springfield Avenue, Greentrees Road',
#  'Irishtown Rd',
#  'Bride St',
#  'Lombard Street',
#  "O'Donovan Rossa Bridge, St Michael's Hill",
#  'Beresford St, Capel St',
#  'Sydney Parade Ave, Merrion Rd, Stillorgan Rd',
#  'Memorial Rd, Beresford Pl, Talbot St, Portland Row, Seville Pl',
#  'Merrion Road, Stillorgan Road',
#  'Grafton St, Dawson St',
#  'Merrion St Upr, Waterloo Rd, Eastmoreland Pl',
#  'Dublin Rd, Bayside Sq, Verbena Ave',
#  "Usher's Qy, Merchant's Qy, Cornmarket, High St",
#  "Ormond Qy, Mary's Abbey, Abbey St Upr, Little Mary St, Mary St, Parnell St, Bolton St",
#  'Strand Rd, Thormanby Rd',
#  'Pembroke Rd, Raglan Rd, Pembroke Park',
#  'Dame St, Grafton St, Westmoreland St',
#  'Church La, Great Georges St S, Parliament St, Cork Hill',
#  "Nassau St, Molesworth St, St Stephen's Green",
#  'Binns Br (Royal Canal), N Circular Rd',
#  'Binns Br (Royal Canal), Clonliffe Rd, Griffith Ave',
#  'North Wall Qy, Sheriff St Upr, Alfie Byrne Rd, North Strand Rd',
#  'Dorset St, Berkeley Rd',
#  'Merrion Row, Baggot St Lwr',
#  'Essex Qy, Wood Qy, Essex St W, Lord Edward St, Christchurch Pl',
#  'Beresford Pl, Talbot St, Parnell St, Summerhill, Dorset Street',
#  'Sandymount Green, Sandymount Ave, Park Ave, Strand Rd',
#  "College Green, Nassau St, Suffolk St, St Stephen's Green",
#  'Dublin Rd, Howth Rd, Strand Rd',
#  "Bolton St, King's Inns",
#  "O'Connell St, Moore St, Liffey St Upr",
#  'Pembroke Road, Morehampton Rd, Donnybrook Rd',
#  'Landsdowne Rd, Tritonville Rd',
#  'Pleasants St, Harrington St',
#  'Fairview, Collins Ave E, Brookwood Ave, Sybil Hill Rd, Station Rd, Main St (Raheny), James Larkin Rd, Kilbarrack Rd',
#  "Leinster St S, Molesworth St, St Stephen's Green",
#  "St Stephen's Green, Grand Parade, Mespil Rd, The Appian Way, Wellington Pl",
#  'Eden Qy, Abbey St Lwr, Earl St N, Talbot St, Parnell St',
#  'School St, Earl St S, Cork Street',
#  'Anglesea Rd, Serpentine Ave',
#  'Fenian St, Clare St, Merrion Square, Merrion Row, Baggot St Lwr',
#  'Dawson St, Kildare St',
#  'Davitt Rd, Kylemore Rd, Walkinstown Rd, M50 motorway, Fonthill Rd S, Belgard Rd, Citywest Rd, ?',
#  'Grafton St, Dawson St, Kildare St',
#  'Herbert Rd, Tritonville Rd',
#  'Summerhill Parade, Dorset St Lwr, Phibsborough Rd, Cabra St, Prussia St, Old Cabra Rd, Infirmary Rd',
#  'Great Denmark Street, Parnell Street',
#  'Portland Row, Seville Pl, Poplar Row, East Wall Rd',
#  'Merrion Rd, Stillorgan Rd',
#  'Bachelors Walk, Eden Qy, Henry St, Earl St N, Parnell St',
#  'Gilford Rd, Sydney Parade Ave',
#  'Essex Qy, Wellington Qy, Lord Edward St, Dame St',
#  "Capel St, Jervis St, Moore St, Parnell Sq, O'Connell St, Gardiner St",
#  "D'Olier St, Tara St, Westland Row, Lombard St E, Erne St, Macken St, MacMahon Br (Grand Canal)",
#  "Northumberland Rd, Clyde Rd, Shelbourne Rd, Ball's Br (River Dodder)",
#  'Pembroke Rd, Clyde Rd',
#  'Merrion Rd, Gilford Rd',
#  'Merrion Rd, Tritonville Road, Claremont Rd',
#  "?, Clanbrassil St, Dolphin's Barn, Suir Rd, Emmet Rd, Inchicore Rd, Con Colbert Rd (N4 road), Chapelizod Rd",
#  'Anglesea Br (River Dodder), Nutley La, Greenfield Park, Mount Merrion Ave, Leopardstown Rd, Newtownpark Ave, Kill La',
#  'Near Merrion Rd, Ailesbury Rd, Park Ave, Strand Rd',
#  'Marlborough St, Gardiner St Lwr, Amiens St',
#  'Temple La, Bedford Row, Anglesea St',
#  'Terenure Road West, Fergus Road, Olney Crescent, Rathdown Park, Lakelands Park, Rathdown Avenue, Terenure College, Fortfield Road, Springfield Road, Templeville Road, Springfield Avenue, Rosehall, Riverside Cottages, Old Bridge Road (Templeogue Bridge), Cypress Grove Road, Corrybeg, Cheeverstown, Templeogue House, Hillcrest, Wellington Road (Spawell Roundabout), M50 motorway',
#  'Templeogue Road, Templeville Park, Fortfield Park, Templeville Avenue, Cypress Grove Road, Wainsfort Road, Wainsfort Crescent, Glendown Road, Grosvenor Court, Wellington Road',
#  'Main St, Carrickbrack Rd',
#  'Londonbridge Rd, Church Ave, Claremont Rd, Serpentine Ave',
#  'Christchurch Pl, Lord Edward St, Bull Alley St, Golden La',
#  'Pearse Street, Lincoln Place',
#  "Merchant's Qy, Wood Qy, High St, Christchurch Pl"]

# %%
ei_streets_list
# Out:
# ['Sráid na Mainistreach',
#  'Bóthar Ailesbury, Bóthar Aelsbaire',
#  'Sráid Amiens',
#  'Bóthar Mon',
#  'Sráid Anna Theas',
#  'Sráid Bhagóid',
#  'Búlbhard Chois Bá',
#  'Sráid an Droichid',
#  'Sráid Chéipil',
#  'Bóthar Charraig Bhreac',
#  'Bóthar Cluaidh',
#  'Faiche an Choláiste',
#  'Sráid an Dáma',
#  'Sráid Dhásain',
#  'Sráid Dorset',
#  'Bóthar Dhroim Conrach',
#  'Bóthar an Phoiirt Thoir',
#  'Sráid Eccles',
#  'Plás Íle',
#  'Sráid Sheamlas an Éisc',
#  'Cearnóg Mhic Liam, Cearnóg Fitzwilliam',
#  'Sráid Ghairdinéir',
#  'Bóthar Gilford',
#  'Sráid Grafton',
#  'Sráid Henrietta',
#  'Sráid Anraí',
#  'Páirc Hoirbeaird',
#  'Bóthar Hoirbeaird',
#  'Sráid Heytesbury',
#  'Bóthar Bhinn Éadair',
#  'Sráid Chill Dara',
#  'Sráid Líosain',
#  'Sráid Mhaoilbhríde, Sráid Maoilbhríde, Sráid Marlborough',
#  'Lána Mhuire Mhaith, Lána Mhuire',
#  'Bóthar Mhuirfean',
#  'Cearnóg Mhuirfean',
#  'Sráid Mhuirfean',
#  'Sráid Theach Laighean',
#  'Cearnóg Mhuinseo',
#  'Bóthar an Náis',
#  'Sráid Thobar Phádraig, Sráid Nassau',
#  'Ascaill an Droichid Nua',
#  'Cuarbhóthar Thuaidh',
#  'Sráid Mór Seóirse Thuaidh',
#  'Bóthar na Trá, Thuaidh',
#  'Lána Nutley, Lána Nothaile',
#  'Sráid Uí Chonaill',
#  'Ascaill na Páirce',
#  'Sráid na Parlaiminte, Sráid na Feise',
#  'Cearnóg Parnell',
#  'Sráid Parnell',
#  'Sráid an Phiarsaigh, Sráid Piarsach',
#  'Bóthar Pheambróg, Bóthar Pembróc, Bóthar Penfro',
#  'Bóthar Raglan, Bóthar Raiglean, Bóthar Rhaglan',
#  'Bóthar Eoin Thoir, Bóthar San Eoin Thoir, Bóthar Eoin',
#  'Faiche Stiabhna, Faiche Stiofáin',
#  'Ascaill Dhumhach Thrá, Ascaill Dumhaighe',
#  'Ascaill na Lúb',
#  'An Cuarbhóthar Theas, Cuarbhóthar Theas',
#  'Bóthar Stigh Lorgan',
#  'Ascaill Pharáid Sydney, Ascaill Pharáid Sidní',
#  'Sráid Talbot, Sráid Thalbóid',
#  'Barra an Teampaill, Barra Temple',
#  'Bóthar Teach Mealóg',
#  'Bóthar Baile an Teampaill',
#  'Bóthar Tritonville',
#  'Sráid San Werburgh, Sráid San Werburga, Sráid Werburgh, Sráid Bhairbre',
#  'Rae an Iarthair',
#  'Sráid an Fhíona']

# %%
# And a lot of the entries are comma-separated street names. Here I'll split these up into separate entries. 
en_sl = [name.split(",") for name in en_streets_list] 
ei_sl = [name.split(",") for name in ei_streets_list]

# %%
# Now flatten the result:
import itertools
en_sl = list(itertools.chain(*en_sl))
ei_sl = list(itertools.chain(*ei_sl))
# And strip out extraneous spaces:
en_streets_list = [el.strip() for el in en_sl]
ei_streets_list = [el.strip() for el in ei_sl]

# %%
en_streets_list
# Out:
# ['Abbey Street',
#  'Ailesbury Road',
#  'Amiens Street',
#  'Anglesea Road',
#  'Anne Street South (South Anne Street)',
#  'Baggot Street',
#  'Bayside Boulevard',
#  'Bridge Street',
#  'Capel Street',
#  'Carrickbrack Road',
#  'Clyde Road',
#  'College Green',
#  'Dame Street',
#  'Dawson Street',
#  'Dorset Street',
#  'Drumcondra Road',
#  'East Wall Road',
#  'Eccles Street',
#  'Ely Place',
#  'Fishamble Street',
#  'Fitzwilliam Square',
#  'Gardiner Street',
#  'Gilford Road',
#  'Grafton Street',
#  'Greenfield Road',
#  'Henrietta Street',
#  'Henry Street',
#  'Herbert Park',
#  'Herbert Road',
#  'Heytesbury Street',
#  'Howth Road',
#  'Kildare Street',
#  'Leeson Street',
#  'Marlborough Street',
#  'Marrowbone Lane',
#  'Merrion Road',
#  'Merrion Square',
#  'Merrion Street',
#  'Molesworth Street',
#  'Mountjoy Square',
#  'Naas Road',
#  'Nassau Street',
#  'Newbridge Avenue',
#  'North Circular Road',
#  "North Great George's Street",
#  'North Strand Road',
#  'Nutley Lane',
#  "O'Connell Street",
#  'Park Avenue',
#  'Parliament Street',
#  'Parnell Square',
#  'Parnell Street',
#  'Pearse Street',
#  'Pembroke Road',
#  'Raglan Road',
#  "St John's Road East (St John's Road)",
#  "St Stephen's Green",
#  'Sandymount Avenue',
#  'Serpentine Avenue',
#  'South Circular Road',
#  'Stillorgan Road',
#  'Sydney Parade Avenue',
#  'Talbot Street',
#  'Temple Bar',
#  'Templeogue Road',
#  'Templeville Road',
#  'Thormanby Road',
#  'Tritonville Road',
#  'Werburgh Street',
#  'Westland Row',
#  'Winetavern Street',
#  "Mary's Abbey",
#  'N Strand Rd',
#  'Beaver Row',
#  'Harry St',
#  'Merrion Row',
#  'Pembroke Rd',
#  'Verbena Lawn (Plásóg Bheirbhéine)',
#  'Fr Mathew Bridge (Droichead an Athar Maitiú)',
#  'Grattan Bridge (Droichead Grattan)',
#  'Greenfield Rd (Bóthar an Ghoirt Ghlais)',
#  'Wellington Pl',
#  'College Green',
#  'Lord Edward St',
#  'Drumcondra Rd',
#  'Bolton St',
#  'Dorset St Lwr',
#  'Swords Rd',
#  'East-Link Toll Bridge',
#  'Poplar Row',
#  'Temple St N',
#  'Merrion St Upr',
#  'Synnott Place',
#  'Seafort Ave',
#  'Westmoreland St',
#  'Station Rd',
#  'Carrickbrack Rd',
#  'Earl St N',
#  'Mary St',
#  'Marlborough Rd',
#  'Stamer St',
#  'New Bridge St',
#  'Dublin Rd',
#  'Morehampton Rd',
#  'Thomas Court',
#  'Pembroke Rd',
#  'Rock Rd',
#  'Merrion Square W',
#  'Ely Place',
#  'Tyrconnell Rd',
#  'Suffolk St',
#  'Leinster St S',
#  'Sandymount Rd',
#  'Portland Row',
#  'Amiens St',
#  'Annesley Bridge Rd',
#  'Greenfield Park',
#  "O'Connell Bridge",
#  'Parnell Sq E',
#  'Grattan Bridge',
#  'Parnell St',
#  'Little Britain St',
#  'Summerhill',
#  'College St',
#  'Ringsend Rd',
#  'Baggot St Upr',
#  'Merrion Rd',
#  'Simmonscourt Rd',
#  'Harrington St',
#  'Bray Rd',
#  'Earl St N',
#  'Essex St E',
#  'Fleet St',
#  'Terenure Place',
#  'Tallaght Road',
#  'Springfield Avenue',
#  'Greentrees Road',
#  'Irishtown Rd',
#  'Bride St',
#  'Lombard Street',
#  "O'Donovan Rossa Bridge",
#  "St Michael's Hill",
#  'Beresford St',
#  'Capel St',
#  'Sydney Parade Ave',
#  'Merrion Rd',
#  'Stillorgan Rd',
#  'Memorial Rd',
#  'Beresford Pl',
#  'Talbot St',
#  'Portland Row',
#  'Seville Pl',
#  'Merrion Road',
#  'Stillorgan Road',
#  'Grafton St',
#  'Dawson St',
#  'Merrion St Upr',
#  'Waterloo Rd',
#  'Eastmoreland Pl',
#  'Dublin Rd',
#  'Bayside Sq',
#  'Verbena Ave',
#  "Usher's Qy",
#  "Merchant's Qy",
#  'Cornmarket',
#  'High St',
#  'Ormond Qy',
#  "Mary's Abbey",
#  'Abbey St Upr',
#  'Little Mary St',
#  'Mary St',
#  'Parnell St',
#  'Bolton St',
#  'Strand Rd',
#  'Thormanby Rd',
#  'Pembroke Rd',
#  'Raglan Rd',
#  'Pembroke Park',
#  'Dame St',
#  'Grafton St',
#  'Westmoreland St',
#  'Church La',
#  'Great Georges St S',
#  'Parliament St',
#  'Cork Hill',
#  'Nassau St',
#  'Molesworth St',
#  "St Stephen's Green",
#  'Binns Br (Royal Canal)',
#  'N Circular Rd',
#  'Binns Br (Royal Canal)',
#  'Clonliffe Rd',
#  'Griffith Ave',
#  'North Wall Qy',
#  'Sheriff St Upr',
#  'Alfie Byrne Rd',
#  'North Strand Rd',
#  'Dorset St',
#  'Berkeley Rd',
#  'Merrion Row',
#  'Baggot St Lwr',
#  'Essex Qy',
#  'Wood Qy',
#  'Essex St W',
#  'Lord Edward St',
#  'Christchurch Pl',
#  'Beresford Pl',
#  'Talbot St',
#  'Parnell St',
#  'Summerhill',
#  'Dorset Street',
#  'Sandymount Green',
#  'Sandymount Ave',
#  'Park Ave',
#  'Strand Rd',
#  'College Green',
#  'Nassau St',
#  'Suffolk St',
#  "St Stephen's Green",
#  'Dublin Rd',
#  'Howth Rd',
#  'Strand Rd',
#  'Bolton St',
#  "King's Inns",
#  "O'Connell St",
#  'Moore St',
#  'Liffey St Upr',
#  'Pembroke Road',
#  'Morehampton Rd',
#  'Donnybrook Rd',
#  'Landsdowne Rd',
#  'Tritonville Rd',
#  'Pleasants St',
#  'Harrington St',
#  'Fairview',
#  'Collins Ave E',
#  'Brookwood Ave',
#  'Sybil Hill Rd',
#  'Station Rd',
#  'Main St (Raheny)',
#  'James Larkin Rd',
#  'Kilbarrack Rd',
#  'Leinster St S',
#  'Molesworth St',
#  "St Stephen's Green",
#  "St Stephen's Green",
#  'Grand Parade',
#  'Mespil Rd',
#  'The Appian Way',
#  'Wellington Pl',
#  'Eden Qy',
#  'Abbey St Lwr',
#  'Earl St N',
#  'Talbot St',
#  'Parnell St',
#  'School St',
#  'Earl St S',
#  'Cork Street',
#  'Anglesea Rd',
#  'Serpentine Ave',
#  'Fenian St',
#  'Clare St',
#  'Merrion Square',
#  'Merrion Row',
#  'Baggot St Lwr',
#  'Dawson St',
#  'Kildare St',
#  'Davitt Rd',
#  'Kylemore Rd',
#  'Walkinstown Rd',
#  'M50 motorway',
#  'Fonthill Rd S',
#  'Belgard Rd',
#  'Citywest Rd',
#  '?',
#  'Grafton St',
#  'Dawson St',
#  'Kildare St',
#  'Herbert Rd',
#  'Tritonville Rd',
#  'Summerhill Parade',
#  'Dorset St Lwr',
#  'Phibsborough Rd',
#  'Cabra St',
#  'Prussia St',
#  'Old Cabra Rd',
#  'Infirmary Rd',
#  'Great Denmark Street',
#  'Parnell Street',
#  'Portland Row',
#  'Seville Pl',
#  'Poplar Row',
#  'East Wall Rd',
#  'Merrion Rd',
#  'Stillorgan Rd',
#  'Bachelors Walk',
#  'Eden Qy',
#  'Henry St',
#  'Earl St N',
#  'Parnell St',
#  'Gilford Rd',
#  'Sydney Parade Ave',
#  'Essex Qy',
#  'Wellington Qy',
#  'Lord Edward St',
#  'Dame St',
#  'Capel St',
#  'Jervis St',
#  'Moore St',
#  'Parnell Sq',
#  "O'Connell St",
#  'Gardiner St',
#  "D'Olier St",
#  'Tara St',
#  'Westland Row',
#  'Lombard St E',
#  'Erne St',
#  'Macken St',
#  'MacMahon Br (Grand Canal)',
#  'Northumberland Rd',
#  'Clyde Rd',
#  'Shelbourne Rd',
#  "Ball's Br (River Dodder)",
#  'Pembroke Rd',
#  'Clyde Rd',
#  'Merrion Rd',
#  'Gilford Rd',
#  'Merrion Rd',
#  'Tritonville Road',
#  'Claremont Rd',
#  '?',
#  'Clanbrassil St',
#  "Dolphin's Barn",
#  'Suir Rd',
#  'Emmet Rd',
#  'Inchicore Rd',
#  'Con Colbert Rd (N4 road)',
#  'Chapelizod Rd',
#  'Anglesea Br (River Dodder)',
#  'Nutley La',
#  'Greenfield Park',
#  'Mount Merrion Ave',
#  'Leopardstown Rd',
#  'Newtownpark Ave',
#  'Kill La',
#  'Near Merrion Rd',
#  'Ailesbury Rd',
#  'Park Ave',
#  'Strand Rd',
#  'Marlborough St',
#  'Gardiner St Lwr',
#  'Amiens St',
#  'Temple La',
#  'Bedford Row',
#  'Anglesea St',
#  'Terenure Road West',
#  'Fergus Road',
#  'Olney Crescent',
#  'Rathdown Park',
#  'Lakelands Park',
#  'Rathdown Avenue',
#  'Terenure College',
#  'Fortfield Road',
#  'Springfield Road',
#  'Templeville Road',
#  'Springfield Avenue',
#  'Rosehall',
#  'Riverside Cottages',
#  'Old Bridge Road (Templeogue Bridge)',
#  'Cypress Grove Road',
#  'Corrybeg',
#  'Cheeverstown',
#  'Templeogue House',
#  'Hillcrest',
#  'Wellington Road (Spawell Roundabout)',
#  'M50 motorway',
#  'Templeogue Road',
#  'Templeville Park',
#  'Fortfield Park',
#  'Templeville Avenue',
#  'Cypress Grove Road',
#  'Wainsfort Road',
#  'Wainsfort Crescent',
#  'Glendown Road',
#  'Grosvenor Court',
#  'Wellington Road',
#  'Main St',
#  'Carrickbrack Rd',
#  'Londonbridge Rd',
#  'Church Ave',
#  'Claremont Rd',
#  'Serpentine Ave',
#  'Christchurch Pl',
#  'Lord Edward St',
#  'Bull Alley St',
#  'Golden La',
#  'Pearse Street',
#  'Lincoln Place',
#  "Merchant's Qy",
#  'Wood Qy',
#  'High St',
#  'Christchurch Pl']

# %%
ei_streets_list
# Out:
# ['Sráid na Mainistreach',
#  'Bóthar Ailesbury',
#  'Bóthar Aelsbaire',
#  'Sráid Amiens',
#  'Bóthar Mon',
#  'Sráid Anna Theas',
#  'Sráid Bhagóid',
#  'Búlbhard Chois Bá',
#  'Sráid an Droichid',
#  'Sráid Chéipil',
#  'Bóthar Charraig Bhreac',
#  'Bóthar Cluaidh',
#  'Faiche an Choláiste',
#  'Sráid an Dáma',
#  'Sráid Dhásain',
#  'Sráid Dorset',
#  'Bóthar Dhroim Conrach',
#  'Bóthar an Phoiirt Thoir',
#  'Sráid Eccles',
#  'Plás Íle',
#  'Sráid Sheamlas an Éisc',
#  'Cearnóg Mhic Liam',
#  'Cearnóg Fitzwilliam',
#  'Sráid Ghairdinéir',
#  'Bóthar Gilford',
#  'Sráid Grafton',
#  'Sráid Henrietta',
#  'Sráid Anraí',
#  'Páirc Hoirbeaird',
#  'Bóthar Hoirbeaird',
#  'Sráid Heytesbury',
#  'Bóthar Bhinn Éadair',
#  'Sráid Chill Dara',
#  'Sráid Líosain',
#  'Sráid Mhaoilbhríde',
#  'Sráid Maoilbhríde',
#  'Sráid Marlborough',
#  'Lána Mhuire Mhaith',
#  'Lána Mhuire',
#  'Bóthar Mhuirfean',
#  'Cearnóg Mhuirfean',
#  'Sráid Mhuirfean',
#  'Sráid Theach Laighean',
#  'Cearnóg Mhuinseo',
#  'Bóthar an Náis',
#  'Sráid Thobar Phádraig',
#  'Sráid Nassau',
#  'Ascaill an Droichid Nua',
#  'Cuarbhóthar Thuaidh',
#  'Sráid Mór Seóirse Thuaidh',
#  'Bóthar na Trá',
#  'Thuaidh',
#  'Lána Nutley',
#  'Lána Nothaile',
#  'Sráid Uí Chonaill',
#  'Ascaill na Páirce',
#  'Sráid na Parlaiminte',
#  'Sráid na Feise',
#  'Cearnóg Parnell',
#  'Sráid Parnell',
#  'Sráid an Phiarsaigh',
#  'Sráid Piarsach',
#  'Bóthar Pheambróg',
#  'Bóthar Pembróc',
#  'Bóthar Penfro',
#  'Bóthar Raglan',
#  'Bóthar Raiglean',
#  'Bóthar Rhaglan',
#  'Bóthar Eoin Thoir',
#  'Bóthar San Eoin Thoir',
#  'Bóthar Eoin',
#  'Faiche Stiabhna',
#  'Faiche Stiofáin',
#  'Ascaill Dhumhach Thrá',
#  'Ascaill Dumhaighe',
#  'Ascaill na Lúb',
#  'An Cuarbhóthar Theas',
#  'Cuarbhóthar Theas',
#  'Bóthar Stigh Lorgan',
#  'Ascaill Pharáid Sydney',
#  'Ascaill Pharáid Sidní',
#  'Sráid Talbot',
#  'Sráid Thalbóid',
#  'Barra an Teampaill',
#  'Barra Temple',
#  'Bóthar Teach Mealóg',
#  'Bóthar Baile an Teampaill',
#  'Bóthar Tritonville',
#  'Sráid San Werburgh',
#  'Sráid San Werburga',
#  'Sráid Werburgh',
#  'Sráid Bhairbre',
#  'Rae an Iarthair',
#  'Sráid an Fhíona']

# %%
# Finally, get synonyms for "pub":
# This url has good info, but it's not easy to scrape: 
# pub_url = r"https://www.macmillandictionary.com/thesaurus-category/british/bars-pubs-and-clubs"
# Instead, I copied-and-pasted from that page into a local file.
# Looking through that file, I see that though the line-returns are screwy, each synonym is on a line by itself,
# ending with the word "noun". So it's easy to extract the terms themselves....
import sys, os
pub_file_path = os.path.abspath(os.path.join(".", "pub_synonyms.txt"))

# %%
pub_syns = []
with open(pub_file_path, 'r') as fp:
    for line in fp:
        if line.endswith("noun\n"):
            pub_syns.append(line.strip("noun\n").strip())

# %%
# Remove the duplicates (e.g. "shebeen")
pub_syns = list(set(pub_syns))

# %%
# Also, I notice that "brewpub", "brewery", "brew house" aren't included...
pub_syns += ["brewpub", "brew pub", "brewery", "brew house", "ale house"]

# %%
pub_syns
# Out:
# ['saloon',
#  'bar',
#  'coaching inn',
#  'free house',
#  'hostelry',
#  'alehouse',
#  'local',
#  'lounge',
#  'beer garden',
#  'bistro',
#  'social club',
#  'joint',
#  'boozer',
#  'gastropub',
#  'pub',
#  'roadhouse',
#  'tavern',
#  'shebeen',
#  'hotel',
#  'wine bar',
#  'inn',
#  'speakeasy',
#  'club',
#  'the house',
#  'honky-tonk',
#  'public house',
#  'watering hole',
#  'dive',
#  'brewpub',
#  'brew pub',
#  'brewery',
#  'brew house',
#  'ale house']

# %%
# I'll save these lists locally, for easy importation and use later:
with open("names_list.txt", 'w') as file_obj:
    for item in names_list:
        file_obj.write(f"{item}\n")

# %%
with open("English_streets_list.txt", 'w') as file_obj:
    for item in en_streets_list:
        file_obj.write(f"{item}\n")
        
with open("Irish_streets_list.txt", 'w') as file_obj:
    for item in ei_streets_list:
        file_obj.write(f"{item}\n")

# %%
with open("pubs_list.txt", 'w') as file_obj:
    for item in pub_syns:
        file_obj.write(f"{item}\n")
